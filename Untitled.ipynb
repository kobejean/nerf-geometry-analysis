# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
output_dir  = "/home/ccl/outputs/long_plane_semisphere/nga-instant-ngp/2023-09-27_130706"
surface_diff = np.load(output_dir + "/renders/z.npy")
img = plt.imread(output_dir + "/renders/rgb.png")

# %%
plt.imshow(surface_diff)

# %%
plt.imshow(img[:,:,0])
